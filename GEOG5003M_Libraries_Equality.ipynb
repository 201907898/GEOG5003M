# %% [markdown]
# <a href="https://colab.research.google.com/github/201907898/GEOG5003M/blob/main/GEOG5003M_Libraries_Equality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GEOG5003M Programming for Geographical Information Analysis
#
# Spatial Data Science Report
#
# 201907898
#
#
# Library Use and Neighbourhood Equality in Manitoba, Canada
